# %%
words = ['w1', 'w2', 'w3']
docs = ['d1', 'd2']
topics = ['z1', 'z2']
n_wd = {'d1': {'w1': 2, 'w2': 1, 'w3': 0}, 'd2': {'w1': 0, 'w2': 1, 'w3': 2}}

P_z_d = {'d1': {'z1': 0.65, 'z2': 0.35}, 'd2': {'z1': 0.8, 'z2': 0.2}}
P_w_z = {'z1': {'w1': 0.45, 'w2': 0.3, 'w3': 0.25}, 'z2': {'w1': 0.7, 'w2': 0.2, 'w3': 0.1}}

def calc_responsibility(P_z_d, P_w_z):
    resp = {}
    for d in docs:
        resp[d] = {}
        for w in words:
            denom = sum(P_z_d[d][z] * P_w_z[z][w] for z in topics)
            resp[d][w] = {}
            for z in topics:
                num = P_z_d[d][z] * P_w_z[z][w]
                resp[d][w][z] = num / denom if denom != 0 else 0
    return resp

def flatten_responsibility(resp):
    flat = []
    for d in docs:
        for w in words:
            for z in topics:
                flat.append(resp[d][w][z])
    return flat

def flatten_params(P_w_z, P_z_d):
    flat_pwz = []
    for z in topics:
        for w in words:
            flat_pwz.append(P_w_z[z][w])
    flat_pzd = []
    for d in docs:
        for z in topics:
            flat_pzd.append(P_z_d[d][z])
    return flat_pwz, flat_pzd

def l1_diff_list(a, b):
    return [abs(x - y) for x, y in zip(a, b)]

tolerance = 0.1
max_iter = 50

prev_resp = None
prev_pwz = None
prev_pzd = None

for iteration in range(1, max_iter+1):
    print("\n====================")
    print(f"Iteration {iteration}")
    print("====================\n")
    
    # E-step
    resp = calc_responsibility(P_z_d, P_w_z)
    print("E-step: Calculate P(z|d,w) for every (d,w,z):")
    for d in docs:
        for w in words:
            denom = sum(P_z_d[d][z] * P_w_z[z][w] for z in topics)
            for z in topics:
                num = P_z_d[d][z] * P_w_z[z][w]
                print(f"P({z}|{d},{w}) = P({z}|{d}) * P({w}|{z}) / sum_z' P(z'|{d}) * P({w}|z') = {P_z_d[d][z]:.4f} * {P_w_z[z][w]:.4f} / {denom:.4f} = {resp[d][w][z]:.4f}")
    print()

    # M-step: Update P(w|z)
    print("M-step: Update P(w|z):")
    new_P_w_z = {z: {} for z in topics}
    for z in topics:
        numerator_sum = 0
        numerators = {}
        for w in words:
            numerators[w] = sum(n_wd[d][w] * resp[d][w][z] for d in docs)
            numerator_sum += numerators[w]
        for w in words:
            result = numerators[w] / numerator_sum if numerator_sum else 0
            new_P_w_z[z][w] = result
            print(f"P({w}|{z}) numerator = Sum_d n({w},d)*P({z}|d,{w}) = {numerators[w]:.4f}, denominator = {numerator_sum:.4f}, result = {result:.4f}")
    print()
    
    # M-step: Update P(z|d)
    print("M-step: Update P(z|d):")
    new_P_z_d = {d: {} for d in docs}
    for d in docs:
        numerator_sum = 0
        numerators = {}
        for z in topics:
            numerators[z] = sum(n_wd[d][w] * resp[d][w][z] for w in words)
            numerator_sum += numerators[z]
        for z in topics:
            result = numerators[z] / numerator_sum if numerator_sum else 0
            new_P_z_d[d][z] = result
            print(f"P({z}|{d}) numerator = Sum_w n({w},d)*P({z}|d,{w}) = {numerators[z]:.4f}, denominator = {numerator_sum:.4f}, result = {result:.4f}")
    print()

    # Compute differences for convergence
    flat_resp = flatten_responsibility(resp)
    flat_pwz_new, flat_pzd_new = flatten_params(new_P_w_z, new_P_z_d)

    if prev_resp is not None:
        resp_diffs = l1_diff_list(prev_resp, flat_resp)
        pwz_diffs = l1_diff_list(prev_pwz, flat_pwz_new)
        pzd_diffs = l1_diff_list(prev_pzd, flat_pzd_new)

        print("Differences for E-step responsibilities:")
        for i, v in enumerate(resp_diffs, 1):
            print(f"  Responsibility {i}: {v:.6f}")
        print("Differences for M-step P(w|z):")
        for i, v in enumerate(pwz_diffs, 1):
            print(f"  P(w|z) {i}: {v:.6f}")
        print("Differences for M-step P(z|d):")
        for i, v in enumerate(pzd_diffs, 1):
            print(f"  P(z|d) {i}: {v:.6f}")

        if all(v < tolerance for v in resp_diffs) and all(v < tolerance for v in pwz_diffs) and all(v < tolerance for v in pzd_diffs):
            print(f"\nConverged at iteration {iteration}")
            break
        else:
            print("\nNo convergence yet\n")

    prev_resp = flat_resp
    prev_pwz = flat_pwz_new
    prev_pzd = flat_pzd_new

    P_w_z = new_P_w_z
    P_z_d = new_P_z_d

if iteration == max_iter:
    print(f"Stopped after maximum iterations ({max_iter}) without full convergence.")
# Out:
# ====================
# Iteration 1
# ====================
#
# E-step: Calculate P(z|d,w) for every (d,w,z):
# P(z1|d1,w1) = P(z1|d1) * P(w1|z1) / sum_z' P(z'|d1) * P(w1|z') = 0.6500 * 0.4500 / 0.5375 = 0.5442
# P(z2|d1,w1) = P(z2|d1) * P(w1|z2) / sum_z' P(z'|d1) * P(w1|z') = 0.3500 * 0.7000 / 0.5375 = 0.4558
# P(z1|d1,w2) = P(z1|d1) * P(w2|z1) / sum_z' P(z'|d1) * P(w2|z') = 0.6500 * 0.3000 / 0.2650 = 0.7358
# P(z2|d1,w2) = P(z2|d1) * P(w2|z2) / sum_z' P(z'|d1) * P(w2|z') = 0.3500 * 0.2000 / 0.2650 = 0.2642
# P(z1|d1,w3) = P(z1|d1) * P(w3|z1) / sum_z' P(z'|d1) * P(w3|z') = 0.6500 * 0.2500 / 0.1975 = 0.8228
# P(z2|d1,w3) = P(z2|d1) * P(w3|z2) / sum_z' P(z'|d1) * P(w3|z') = 0.3500 * 0.1000 / 0.1975 = 0.1772
# P(z1|d2,w1) = P(z1|d2) * P(w1|z1) / sum_z' P(z'|d2) * P(w1|z') = 0.8000 * 0.4500 / 0.5000 = 0.7200
# P(z2|d2,w1) = P(z2|d2) * P(w1|z2) / sum_z' P(z'|d2) * P(w1|z') = 0.2000 * 0.7000 / 0.5000 = 0.2800
# P(z1|d2,w2) = P(z1|d2) * P(w2|z1) / sum_z' P(z'|d2) * P(w2|z') = 0.8000 * 0.3000 / 0.2800 = 0.8571
# P(z2|d2,w2) = P(z2|d2) * P(w2|z2) / sum_z' P(z'|d2) * P(w2|z') = 0.2000 * 0.2000 / 0.2800 = 0.1429
# P(z1|d2,w3) = P(z1|d2) * P(w3|z1) / sum_z' P(z'|d2) * P(w3|z') = 0.8000 * 0.2500 / 0.2200 = 0.9091
# P(z2|d2,w3) = P(z2|d2) * P(w3|z2) / sum_z' P(z'|d2) * P(w3|z') = 0.2000 * 0.1000 / 0.2200 = 0.0909
#
# M-step: Update P(w|z):
# P(w1|z1) numerator = Sum_d n(w1,d)*P(z1|d,w1) = 1.0884, denominator = 4.4995, result = 0.2419
# P(w2|z1) numerator = Sum_d n(w2,d)*P(z1|d,w2) = 1.5930, denominator = 4.4995, result = 0.3540
# P(w3|z1) numerator = Sum_d n(w3,d)*P(z1|d,w3) = 1.8182, denominator = 4.4995, result = 0.4041
# P(w1|z2) numerator = Sum_d n(w1,d)*P(z2|d,w1) = 0.9116, denominator = 1.5005, result = 0.6076
# P(w2|z2) numerator = Sum_d n(w2,d)*P(z2|d,w2) = 0.4070, denominator = 1.5005, result = 0.2713
# P(w3|z2) numerator = Sum_d n(w3,d)*P(z2|d,w3) = 0.1818, denominator = 1.5005, result = 0.1212
#
# M-step: Update P(z|d):
# P(z1|d1) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 1.8242, denominator = 3.0000, result = 0.6081
# P(z2|d1) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 1.1758, denominator = 3.0000, result = 0.3919
# P(z1|d2) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 2.6753, denominator = 3.0000, result = 0.8918
# P(z2|d2) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 0.3247, denominator = 3.0000, result = 0.1082
#
#
# ====================
# Iteration 2
# ====================
#
# E-step: Calculate P(z|d,w) for every (d,w,z):
# P(z1|d1,w1) = P(z1|d1) * P(w1|z1) / sum_z' P(z'|d1) * P(w1|z') = 0.6081 * 0.2419 / 0.3852 = 0.3818
# P(z2|d1,w1) = P(z2|d1) * P(w1|z2) / sum_z' P(z'|d1) * P(w1|z') = 0.3919 * 0.6076 / 0.3852 = 0.6182
# P(z1|d1,w2) = P(z1|d1) * P(w2|z1) / sum_z' P(z'|d1) * P(w2|z') = 0.6081 * 0.3540 / 0.3216 = 0.6694
# P(z2|d1,w2) = P(z2|d1) * P(w2|z2) / sum_z' P(z'|d1) * P(w2|z') = 0.3919 * 0.2713 / 0.3216 = 0.3306
# P(z1|d1,w3) = P(z1|d1) * P(w3|z1) / sum_z' P(z'|d1) * P(w3|z') = 0.6081 * 0.4041 / 0.2932 = 0.8380
# P(z2|d1,w3) = P(z2|d1) * P(w3|z2) / sum_z' P(z'|d1) * P(w3|z') = 0.3919 * 0.1212 / 0.2932 = 0.1620
# P(z1|d2,w1) = P(z1|d2) * P(w1|z1) / sum_z' P(z'|d2) * P(w1|z') = 0.8918 * 0.2419 / 0.2815 = 0.7664
# P(z2|d2,w1) = P(z2|d2) * P(w1|z2) / sum_z' P(z'|d2) * P(w1|z') = 0.1082 * 0.6076 / 0.2815 = 0.2336
# P(z1|d2,w2) = P(z1|d2) * P(w2|z1) / sum_z' P(z'|d2) * P(w2|z') = 0.8918 * 0.3540 / 0.3451 = 0.9149
# P(z2|d2,w2) = P(z2|d2) * P(w2|z2) / sum_z' P(z'|d2) * P(w2|z') = 0.1082 * 0.2713 / 0.3451 = 0.0851
# P(z1|d2,w3) = P(z1|d2) * P(w3|z1) / sum_z' P(z'|d2) * P(w3|z') = 0.8918 * 0.4041 / 0.3735 = 0.9649
# P(z2|d2,w3) = P(z2|d2) * P(w3|z2) / sum_z' P(z'|d2) * P(w3|z') = 0.1082 * 0.1212 / 0.3735 = 0.0351
#
# M-step: Update P(w|z):
# P(w1|z1) numerator = Sum_d n(w1,d)*P(z1|d,w1) = 0.7637, denominator = 4.2778, result = 0.1785
# P(w2|z1) numerator = Sum_d n(w2,d)*P(z1|d,w2) = 1.5843, denominator = 4.2778, result = 0.3704
# P(w3|z1) numerator = Sum_d n(w3,d)*P(z1|d,w3) = 1.9298, denominator = 4.2778, result = 0.4511
# P(w1|z2) numerator = Sum_d n(w1,d)*P(z2|d,w1) = 1.2363, denominator = 1.7222, result = 0.7179
# P(w2|z2) numerator = Sum_d n(w2,d)*P(z2|d,w2) = 0.4157, denominator = 1.7222, result = 0.2413
# P(w3|z2) numerator = Sum_d n(w3,d)*P(z2|d,w3) = 0.0702, denominator = 1.7222, result = 0.0408
#
# M-step: Update P(z|d):
# P(z1|d1) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 1.4331, denominator = 3.0000, result = 0.4777
# P(z2|d1) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 1.5669, denominator = 3.0000, result = 0.5223
# P(z1|d2) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 2.8447, denominator = 3.0000, result = 0.9482
# P(z2|d2) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 0.1553, denominator = 3.0000, result = 0.0518
#
# Differences for E-step responsibilities:
#   Responsibility 1: 0.162354
#   Responsibility 2: 0.162354
#   Responsibility 3: 0.066432
#   Responsibility 4: 0.066432
#   Responsibility 5: 0.015239
#   Responsibility 6: 0.015239
#   Responsibility 7: 0.046383
#   Responsibility 8: 0.046383
#   Responsibility 9: 0.057784
#   Responsibility 10: 0.057784
#   Responsibility 11: 0.055794
#   Responsibility 12: 0.055794
# Differences for M-step P(w|z):
#   P(w|z) 1: 0.063366
#   P(w|z) 2: 0.016332
#   P(w|z) 3: 0.047034
#   P(w|z) 4: 0.110304
#   P(w|z) 5: 0.029908
#   P(w|z) 6: 0.080397
# Differences for M-step P(z|d):
#   P(z|d) 1: 0.130380
#   P(z|d) 2: 0.130380
#   P(z|d) 3: 0.056457
#   P(z|d) 4: 0.056457
#
# No convergence yet
#
#
# ====================
# Iteration 3
# ====================
#
# E-step: Calculate P(z|d,w) for every (d,w,z):
# P(z1|d1,w1) = P(z1|d1) * P(w1|z1) / sum_z' P(z'|d1) * P(w1|z') = 0.4777 * 0.1785 / 0.4602 = 0.1853
# P(z2|d1,w1) = P(z2|d1) * P(w1|z2) / sum_z' P(z'|d1) * P(w1|z') = 0.5223 * 0.7179 / 0.4602 = 0.8147
# P(z1|d1,w2) = P(z1|d1) * P(w2|z1) / sum_z' P(z'|d1) * P(w2|z') = 0.4777 * 0.3704 / 0.3030 = 0.5839
# P(z2|d1,w2) = P(z2|d1) * P(w2|z2) / sum_z' P(z'|d1) * P(w2|z') = 0.5223 * 0.2413 / 0.3030 = 0.4161
# P(z1|d1,w3) = P(z1|d1) * P(w3|z1) / sum_z' P(z'|d1) * P(w3|z') = 0.4777 * 0.4511 / 0.2368 = 0.9101
# P(z2|d1,w3) = P(z2|d1) * P(w3|z2) / sum_z' P(z'|d1) * P(w3|z') = 0.5223 * 0.0408 / 0.2368 = 0.0899
# P(z1|d2,w1) = P(z1|d2) * P(w1|z1) / sum_z' P(z'|d2) * P(w1|z') = 0.9482 * 0.1785 / 0.2064 = 0.8200
# P(z2|d2,w1) = P(z2|d2) * P(w1|z2) / sum_z' P(z'|d2) * P(w1|z') = 0.0518 * 0.7179 / 0.2064 = 0.1800
# P(z1|d2,w2) = P(z1|d2) * P(w2|z1) / sum_z' P(z'|d2) * P(w2|z') = 0.9482 * 0.3704 / 0.3637 = 0.9656
# P(z2|d2,w2) = P(z2|d2) * P(w2|z2) / sum_z' P(z'|d2) * P(w2|z') = 0.0518 * 0.2413 / 0.3637 = 0.0344
# P(z1|d2,w3) = P(z1|d2) * P(w3|z1) / sum_z' P(z'|d2) * P(w3|z') = 0.9482 * 0.4511 / 0.4299 = 0.9951
# P(z2|d2,w3) = P(z2|d2) * P(w3|z2) / sum_z' P(z'|d2) * P(w3|z') = 0.0518 * 0.0408 / 0.4299 = 0.0049
#
# M-step: Update P(w|z):
# P(w1|z1) numerator = Sum_d n(w1,d)*P(z1|d,w1) = 0.3706, denominator = 3.9104, result = 0.0948
# P(w2|z1) numerator = Sum_d n(w2,d)*P(z1|d,w2) = 1.5496, denominator = 3.9104, result = 0.3963
# P(w3|z1) numerator = Sum_d n(w3,d)*P(z1|d,w3) = 1.9902, denominator = 3.9104, result = 0.5090
# P(w1|z2) numerator = Sum_d n(w1,d)*P(z2|d,w1) = 1.6294, denominator = 2.0896, result = 0.7798
# P(w2|z2) numerator = Sum_d n(w2,d)*P(z2|d,w2) = 0.4504, denominator = 2.0896, result = 0.2155
# P(w3|z2) numerator = Sum_d n(w3,d)*P(z2|d,w3) = 0.0098, denominator = 2.0896, result = 0.0047
#
# M-step: Update P(z|d):
# P(z1|d1) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 0.9545, denominator = 3.0000, result = 0.3182
# P(z2|d1) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 2.0455, denominator = 3.0000, result = 0.6818
# P(z1|d2) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 2.9558, denominator = 3.0000, result = 0.9853
# P(z2|d2) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 0.0442, denominator = 3.0000, result = 0.0147
#
# Differences for E-step responsibilities:
#   Responsibility 1: 0.196538
#   Responsibility 2: 0.196538
#   Responsibility 3: 0.085478
#   Responsibility 4: 0.085478
#   Responsibility 5: 0.072028
#   Responsibility 6: 0.072028
#   Responsibility 7: 0.053600
#   Responsibility 8: 0.053600
#   Responsibility 9: 0.050719
#   Responsibility 10: 0.050719
#   Responsibility 11: 0.030204
#   Responsibility 12: 0.030204
# Differences for M-step P(w|z):
#   P(w|z) 1: 0.083748
#   P(w|z) 2: 0.025912
#   P(w|z) 3: 0.057836
#   P(w|z) 4: 0.061882
#   P(w|z) 5: 0.025803
#   P(w|z) 6: 0.036079
# Differences for M-step P(z|d):
#   P(z|d) 1: 0.159518
#   P(z|d) 2: 0.159518
#   P(z|d) 3: 0.037043
#   P(z|d) 4: 0.037043
#
# No convergence yet
#
#
# ====================
# Iteration 4
# ====================
#
# E-step: Calculate P(z|d,w) for every (d,w,z):
# P(z1|d1,w1) = P(z1|d1) * P(w1|z1) / sum_z' P(z'|d1) * P(w1|z') = 0.3182 * 0.0948 / 0.5618 = 0.0537
# P(z2|d1,w1) = P(z2|d1) * P(w1|z2) / sum_z' P(z'|d1) * P(w1|z') = 0.6818 * 0.7798 / 0.5618 = 0.9463
# P(z1|d1,w2) = P(z1|d1) * P(w2|z1) / sum_z' P(z'|d1) * P(w2|z') = 0.3182 * 0.3963 / 0.2731 = 0.4618
# P(z2|d1,w2) = P(z2|d1) * P(w2|z2) / sum_z' P(z'|d1) * P(w2|z') = 0.6818 * 0.2155 / 0.2731 = 0.5382
# P(z1|d1,w3) = P(z1|d1) * P(w3|z1) / sum_z' P(z'|d1) * P(w3|z') = 0.3182 * 0.5090 / 0.1651 = 0.9806
# P(z2|d1,w3) = P(z2|d1) * P(w3|z2) / sum_z' P(z'|d1) * P(w3|z') = 0.6818 * 0.0047 / 0.1651 = 0.0194
# P(z1|d2,w1) = P(z1|d2) * P(w1|z1) / sum_z' P(z'|d2) * P(w1|z') = 0.9853 * 0.0948 / 0.1049 = 0.8905
# P(z2|d2,w1) = P(z2|d2) * P(w1|z2) / sum_z' P(z'|d2) * P(w1|z') = 0.0147 * 0.7798 / 0.1049 = 0.1095
# P(z1|d2,w2) = P(z1|d2) * P(w2|z1) / sum_z' P(z'|d2) * P(w2|z') = 0.9853 * 0.3963 / 0.3936 = 0.9919
# P(z2|d2,w2) = P(z2|d2) * P(w2|z2) / sum_z' P(z'|d2) * P(w2|z') = 0.0147 * 0.2155 / 0.3936 = 0.0081
# P(z1|d2,w3) = P(z1|d2) * P(w3|z1) / sum_z' P(z'|d2) * P(w3|z') = 0.9853 * 0.5090 / 0.5015 = 0.9999
# P(z2|d2,w3) = P(z2|d2) * P(w3|z2) / sum_z' P(z'|d2) * P(w3|z') = 0.0147 * 0.0047 / 0.5015 = 0.0001
#
# M-step: Update P(w|z):
# P(w1|z1) numerator = Sum_d n(w1,d)*P(z1|d,w1) = 0.1073, denominator = 3.5608, result = 0.0301
# P(w2|z1) numerator = Sum_d n(w2,d)*P(z1|d,w2) = 1.4537, denominator = 3.5608, result = 0.4083
# P(w3|z1) numerator = Sum_d n(w3,d)*P(z1|d,w3) = 1.9997, denominator = 3.5608, result = 0.5616
# P(w1|z2) numerator = Sum_d n(w1,d)*P(z2|d,w1) = 1.8927, denominator = 2.4392, result = 0.7759
# P(w2|z2) numerator = Sum_d n(w2,d)*P(z2|d,w2) = 0.5463, denominator = 2.4392, result = 0.2240
# P(w3|z2) numerator = Sum_d n(w3,d)*P(z2|d,w3) = 0.0003, denominator = 2.4392, result = 0.0001
#
# M-step: Update P(z|d):
# P(z1|d1) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 0.5691, denominator = 3.0000, result = 0.1897
# P(z2|d1) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 2.4309, denominator = 3.0000, result = 0.8103
# P(z1|d2) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 2.9917, denominator = 3.0000, result = 0.9972
# P(z2|d2) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 0.0083, denominator = 3.0000, result = 0.0028
#
# Differences for E-step responsibilities:
#   Responsibility 1: 0.131621
#   Responsibility 2: 0.131621
#   Responsibility 3: 0.122171
#   Responsibility 4: 0.122171
#   Responsibility 5: 0.070542
#   Responsibility 6: 0.070542
#   Responsibility 7: 0.070516
#   Responsibility 8: 0.070516
#   Responsibility 9: 0.026290
#   Responsibility 10: 0.026290
#   Responsibility 11: 0.004773
#   Responsibility 12: 0.004773
# Differences for M-step P(w|z):
#   P(w|z) 1: 0.064624
#   P(w|z) 2: 0.011978
#   P(w|z) 3: 0.052647
#   P(w|z) 4: 0.003830
#   P(w|z) 5: 0.008417
#   P(w|z) 6: 0.004587
# Differences for M-step P(z|d):
#   P(z|d) 1: 0.128471
#   P(z|d) 2: 0.128471
#   P(z|d) 3: 0.011945
#   P(z|d) 4: 0.011945
#
# No convergence yet
#
#
# ====================
# Iteration 5
# ====================
#
# E-step: Calculate P(z|d,w) for every (d,w,z):
# P(z1|d1,w1) = P(z1|d1) * P(w1|z1) / sum_z' P(z'|d1) * P(w1|z') = 0.1897 * 0.0301 / 0.6344 = 0.0090
# P(z2|d1,w1) = P(z2|d1) * P(w1|z2) / sum_z' P(z'|d1) * P(w1|z') = 0.8103 * 0.7759 / 0.6344 = 0.9910
# P(z1|d1,w2) = P(z1|d1) * P(w2|z1) / sum_z' P(z'|d1) * P(w2|z') = 0.1897 * 0.4083 / 0.2589 = 0.2991
# P(z2|d1,w2) = P(z2|d1) * P(w2|z2) / sum_z' P(z'|d1) * P(w2|z') = 0.8103 * 0.2240 / 0.2589 = 0.7009
# P(z1|d1,w3) = P(z1|d1) * P(w3|z1) / sum_z' P(z'|d1) * P(w3|z') = 0.1897 * 0.5616 / 0.1066 = 0.9991
# P(z2|d1,w3) = P(z2|d1) * P(w3|z2) / sum_z' P(z'|d1) * P(w3|z') = 0.8103 * 0.0001 / 0.1066 = 0.0009
# P(z1|d2,w1) = P(z1|d2) * P(w1|z1) / sum_z' P(z'|d2) * P(w1|z') = 0.9972 * 0.0301 / 0.0322 = 0.9331
# P(z2|d2,w1) = P(z2|d2) * P(w1|z2) / sum_z' P(z'|d2) * P(w1|z') = 0.0028 * 0.7759 / 0.0322 = 0.0669
# P(z1|d2,w2) = P(z1|d2) * P(w2|z1) / sum_z' P(z'|d2) * P(w2|z') = 0.9972 * 0.4083 / 0.4077 = 0.9985
# P(z2|d2,w2) = P(z2|d2) * P(w2|z2) / sum_z' P(z'|d2) * P(w2|z') = 0.0028 * 0.2240 / 0.4077 = 0.0015
# P(z1|d2,w3) = P(z1|d2) * P(w3|z1) / sum_z' P(z'|d2) * P(w3|z') = 0.9972 * 0.5616 / 0.5600 = 1.0000
# P(z2|d2,w3) = P(z2|d2) * P(w3|z2) / sum_z' P(z'|d2) * P(w3|z') = 0.0028 * 0.0001 / 0.5600 = 0.0000
#
# M-step: Update P(w|z):
# P(w1|z1) numerator = Sum_d n(w1,d)*P(z1|d,w1) = 0.0180, denominator = 3.3156, result = 0.0054
# P(w2|z1) numerator = Sum_d n(w2,d)*P(z1|d,w2) = 1.2976, denominator = 3.3156, result = 0.3914
# P(w3|z1) numerator = Sum_d n(w3,d)*P(z1|d,w3) = 2.0000, denominator = 3.3156, result = 0.6032
# P(w1|z2) numerator = Sum_d n(w1,d)*P(z2|d,w1) = 1.9820, denominator = 2.6844, result = 0.7383
# P(w2|z2) numerator = Sum_d n(w2,d)*P(z2|d,w2) = 0.7024, denominator = 2.6844, result = 0.2617
# P(w3|z2) numerator = Sum_d n(w3,d)*P(z2|d,w3) = 0.0000, denominator = 2.6844, result = 0.0000
#
# M-step: Update P(z|d):
# P(z1|d1) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 0.3171, denominator = 3.0000, result = 0.1057
# P(z2|d1) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 2.6829, denominator = 3.0000, result = 0.8943
# P(z1|d2) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 2.9985, denominator = 3.0000, result = 0.9995
# P(z2|d2) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 0.0015, denominator = 3.0000, result = 0.0005
#
# Differences for E-step responsibilities:
#   Responsibility 1: 0.044659
#   Responsibility 2: 0.044659
#   Responsibility 3: 0.162654
#   Responsibility 4: 0.162654
#   Responsibility 5: 0.018546
#   Responsibility 6: 0.018546
#   Responsibility 7: 0.042556
#   Responsibility 8: 0.042556
#   Responsibility 9: 0.006537
#   Responsibility 10: 0.006537
#   Responsibility 11: 0.000137
#   Responsibility 12: 0.000137
# Differences for M-step P(w|z):
#   P(w|z) 1: 0.024709
#   P(w|z) 2: 0.016899
#   P(w|z) 3: 0.041608
#   P(w|z) 4: 0.037591
#   P(w|z) 5: 0.037703
#   P(w|z) 6: 0.000113
# Differences for M-step P(z|d):
#   P(z|d) 1: 0.083990
#   P(z|d) 2: 0.083990
#   P(z|d) 3: 0.002271
#   P(z|d) 4: 0.002271
#
# No convergence yet
#
#
# ====================
# Iteration 6
# ====================
#
# E-step: Calculate P(z|d,w) for every (d,w,z):
# P(z1|d1,w1) = P(z1|d1) * P(w1|z1) / sum_z' P(z'|d1) * P(w1|z') = 0.1057 * 0.0054 / 0.6609 = 0.0009
# P(z2|d1,w1) = P(z2|d1) * P(w1|z2) / sum_z' P(z'|d1) * P(w1|z') = 0.8943 * 0.7383 / 0.6609 = 0.9991
# P(z1|d1,w2) = P(z1|d1) * P(w2|z1) / sum_z' P(z'|d1) * P(w2|z') = 0.1057 * 0.3914 / 0.2754 = 0.1502
# P(z2|d1,w2) = P(z2|d1) * P(w2|z2) / sum_z' P(z'|d1) * P(w2|z') = 0.8943 * 0.2617 / 0.2754 = 0.8498
# P(z1|d1,w3) = P(z1|d1) * P(w3|z1) / sum_z' P(z'|d1) * P(w3|z') = 0.1057 * 0.6032 / 0.0638 = 1.0000
# P(z2|d1,w3) = P(z2|d1) * P(w3|z2) / sum_z' P(z'|d1) * P(w3|z') = 0.8943 * 0.0000 / 0.0638 = 0.0000
# P(z1|d2,w1) = P(z1|d2) * P(w1|z1) / sum_z' P(z'|d2) * P(w1|z') = 0.9995 * 0.0054 / 0.0058 = 0.9353
# P(z2|d2,w1) = P(z2|d2) * P(w1|z2) / sum_z' P(z'|d2) * P(w1|z') = 0.0005 * 0.7383 / 0.0058 = 0.0647
# P(z1|d2,w2) = P(z1|d2) * P(w2|z1) / sum_z' P(z'|d2) * P(w2|z') = 0.9995 * 0.3914 / 0.3913 = 0.9997
# P(z2|d2,w2) = P(z2|d2) * P(w2|z2) / sum_z' P(z'|d2) * P(w2|z') = 0.0005 * 0.2617 / 0.3913 = 0.0003
# P(z1|d2,w3) = P(z1|d2) * P(w3|z1) / sum_z' P(z'|d2) * P(w3|z') = 0.9995 * 0.6032 / 0.6029 = 1.0000
# P(z2|d2,w3) = P(z2|d2) * P(w3|z2) / sum_z' P(z'|d2) * P(w3|z') = 0.0005 * 0.0000 / 0.6029 = 0.0000
#
# M-step: Update P(w|z):
# P(w1|z1) numerator = Sum_d n(w1,d)*P(z1|d,w1) = 0.0017, denominator = 3.1516, result = 0.0006
# P(w2|z1) numerator = Sum_d n(w2,d)*P(z1|d,w2) = 1.1499, denominator = 3.1516, result = 0.3649
# P(w3|z1) numerator = Sum_d n(w3,d)*P(z1|d,w3) = 2.0000, denominator = 3.1516, result = 0.6346
# P(w1|z2) numerator = Sum_d n(w1,d)*P(z2|d,w1) = 1.9983, denominator = 2.8484, result = 0.7015
# P(w2|z2) numerator = Sum_d n(w2,d)*P(z2|d,w2) = 0.8501, denominator = 2.8484, result = 0.2985
# P(w3|z2) numerator = Sum_d n(w3,d)*P(z2|d,w3) = 0.0000, denominator = 2.8484, result = 0.0000
#
# M-step: Update P(z|d):
# P(z1|d1) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 0.1520, denominator = 3.0000, result = 0.0507
# P(z2|d1) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 2.8480, denominator = 3.0000, result = 0.9493
# P(z1|d2) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 2.9997, denominator = 3.0000, result = 0.9999
# P(z2|d2) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 0.0003, denominator = 3.0000, result = 0.0001
#
# Differences for E-step responsibilities:
#   Responsibility 1: 0.008144
#   Responsibility 2: 0.008144
#   Responsibility 3: 0.148877
#   Responsibility 4: 0.148877
#   Responsibility 5: 0.000854
#   Responsibility 6: 0.000854
#   Responsibility 7: 0.002225
#   Responsibility 8: 0.002225
#   Responsibility 9: 0.001186
#   Responsibility 10: 0.001186
#   Responsibility 11: 0.000001
#   Responsibility 12: 0.000001
# Differences for M-step P(w|z):
#   P(w|z) 1: 0.004885
#   P(w|z) 2: 0.026499
#   P(w|z) 3: 0.031385
#   P(w|z) 4: 0.036787
#   P(w|z) 5: 0.036787
#   P(w|z) 6: 0.000000
# Differences for M-step P(z|d):
#   P(z|d) 1: 0.055055
#   P(z|d) 2: 0.055055
#   P(z|d) 3: 0.000396
#   P(z|d) 4: 0.000396
#
# No convergence yet
#
#
# ====================
# Iteration 7
# ====================
#
# E-step: Calculate P(z|d,w) for every (d,w,z):
# P(z1|d1,w1) = P(z1|d1) * P(w1|z1) / sum_z' P(z'|d1) * P(w1|z') = 0.0507 * 0.0006 / 0.6660 = 0.0000
# P(z2|d1,w1) = P(z2|d1) * P(w1|z2) / sum_z' P(z'|d1) * P(w1|z') = 0.9493 * 0.7015 / 0.6660 = 1.0000
# P(z1|d1,w2) = P(z1|d1) * P(w2|z1) / sum_z' P(z'|d1) * P(w2|z') = 0.0507 * 0.3649 / 0.3018 = 0.0612
# P(z2|d1,w2) = P(z2|d1) * P(w2|z2) / sum_z' P(z'|d1) * P(w2|z') = 0.9493 * 0.2985 / 0.3018 = 0.9388
# P(z1|d1,w3) = P(z1|d1) * P(w3|z1) / sum_z' P(z'|d1) * P(w3|z') = 0.0507 * 0.6346 / 0.0321 = 1.0000
# P(z2|d1,w3) = P(z2|d1) * P(w3|z2) / sum_z' P(z'|d1) * P(w3|z') = 0.9493 * 0.0000 / 0.0321 = 0.0000
# P(z1|d2,w1) = P(z1|d2) * P(w1|z1) / sum_z' P(z'|d2) * P(w1|z') = 0.9999 * 0.0006 / 0.0006 = 0.8739
# P(z2|d2,w1) = P(z2|d2) * P(w1|z2) / sum_z' P(z'|d2) * P(w1|z') = 0.0001 * 0.7015 / 0.0006 = 0.1261
# P(z1|d2,w2) = P(z1|d2) * P(w2|z1) / sum_z' P(z'|d2) * P(w2|z') = 0.9999 * 0.3649 / 0.3648 = 0.9999
# P(z2|d2,w2) = P(z2|d2) * P(w2|z2) / sum_z' P(z'|d2) * P(w2|z') = 0.0001 * 0.2985 / 0.3648 = 0.0001
# P(z1|d2,w3) = P(z1|d2) * P(w3|z1) / sum_z' P(z'|d2) * P(w3|z') = 0.9999 * 0.6346 / 0.6345 = 1.0000
# P(z2|d2,w3) = P(z2|d2) * P(w3|z2) / sum_z' P(z'|d2) * P(w3|z') = 0.0001 * 0.0000 / 0.6345 = 0.0000
#
# M-step: Update P(w|z):
# P(w1|z1) numerator = Sum_d n(w1,d)*P(z1|d,w1) = 0.0001, denominator = 3.0612, result = 0.0000
# P(w2|z1) numerator = Sum_d n(w2,d)*P(z1|d,w2) = 1.0611, denominator = 3.0612, result = 0.3466
# P(w3|z1) numerator = Sum_d n(w3,d)*P(z1|d,w3) = 2.0000, denominator = 3.0612, result = 0.6533
# P(w1|z2) numerator = Sum_d n(w1,d)*P(z2|d,w1) = 1.9999, denominator = 2.9388, result = 0.6805
# P(w2|z2) numerator = Sum_d n(w2,d)*P(z2|d,w2) = 0.9389, denominator = 2.9388, result = 0.3195
# P(w3|z2) numerator = Sum_d n(w3,d)*P(z2|d,w3) = 0.0000, denominator = 2.9388, result = 0.0000
#
# M-step: Update P(z|d):
# P(z1|d1) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 0.0613, denominator = 3.0000, result = 0.0204
# P(z2|d1) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 2.9387, denominator = 3.0000, result = 0.9796
# P(z1|d2) numerator = Sum_w n(w3,d)*P(z1|d,w3) = 2.9999, denominator = 3.0000, result = 1.0000
# P(z2|d2) numerator = Sum_w n(w3,d)*P(z2|d,w3) = 0.0001, denominator = 3.0000, result = 0.0000
#
# Differences for E-step responsibilities:
#   Responsibility 1: 0.000828
#   Responsibility 2: 0.000828
#   Responsibility 3: 0.088998
#   Responsibility 4: 0.088998
#   Responsibility 5: 0.000006
#   Responsibility 6: 0.000006
#   Responsibility 7: 0.061401
#   Responsibility 8: 0.061401
#   Responsibility 9: 0.000248
#   Responsibility 10: 0.000248
#   Responsibility 11: 0.000000
#   Responsibility 12: 0.000000
# Differences for M-step P(w|z):
#   P(w|z) 1: 0.000525
#   P(w|z) 2: 0.018216
#   P(w|z) 3: 0.018741
#   P(w|z) 4: 0.021018
#   P(w|z) 5: 0.021018
#   P(w|z) 6: 0.000000
# Differences for M-step P(z|d):
#   P(z|d) 1: 0.030218
#   P(z|d) 2: 0.030218
#   P(z|d) 3: 0.000083
#   P(z|d) 4: 0.000083
#
# Converged at iteration 7
